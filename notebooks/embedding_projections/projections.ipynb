# %%
pip install opentsne
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opentsne
#   Downloading openTSNE-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.11/dist-packages (from opentsne) (1.26.0)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.11/dist-packages (from opentsne) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from opentsne) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20->opentsne) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20->opentsne) (3.2.0)
# Downloading openTSNE-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 3.9 MB/s eta 0:00:000:00:01m eta 0:00:01
# Installing collected packages: opentsne
# Successfully installed opentsne-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append("../..")

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pu.feature_extractors.extractors import ViTExtractor, AutoencoderExtractor
from pu.data.loaders import CSVLoader, SingleCSVLoader, SingleCSVWithTestLoader, SinglePNCSVWithTestLoader
from pu.data.pu_builder import build_pu_data

from pu.algorithms.pu_algorithms import IterativeClassifierAlgorithm, ProbTagging
from pu.algorithms.negative_detectors import NaiveDetector, KNNDetector
from pu.algorithms.stop_criterion import StopOnMetricDrop, NonStop

from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.decomposition import PCA

import openTSNE

def unison_shuffled_copies(a, b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]
# Out:
# 2023-12-20 10:03:02.464733: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-20 10:03:02.489856: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-20 10:03:02.489871: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-20 10:03:02.489887: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-20 10:03:02.496042: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
ava_loader = SinglePNCSVWithTestLoader(
    '/srv/PU-dataset/unlabeled.csv',
    'id',
    '/srv/PU-dataset/dataset_unlabeled',
    positive_fn=lambda row: row['VotesMean'] > 5.0,
    test_frac=0.2,
    random_state=1234
)

paths_train_positive, paths_train_negative, paths_test_positive, paths_test_negative = ava_loader.load_data()

# %%
def tsne_huge(x,y):
    aff50 = openTSNE.affinity.PerplexityBasedNN(
        x,
        perplexity=50,
        n_jobs=32,
        random_state=0,
    )
    
    indices = np.random.permutation(list(range(x.shape[0])))
    reverse = np.argsort(indices)

    x_sample, x_rest = x[indices[:25000]], x[indices[25000:]]
    y_sample, y_rest = y[indices[:25000]], y[indices[25000:]]
    
    sample_affinities = openTSNE.affinity.PerplexityBasedNN(
        x_sample,
        perplexity=500,
        n_jobs=32,
        random_state=0,
        verbose=True,
    )

    sample_init = openTSNE.initialization.pca(x_sample, random_state=42)
    sample_embedding = openTSNE.TSNE(n_jobs=-1, verbose=True).fit(affinities=sample_affinities, initialization=sample_init)
    
    rest_init = sample_embedding.prepare_partial(x_rest, k=1, perplexity=1/3)
    init_full = np.vstack((sample_embedding, rest_init))[reverse]
    init_full = init_full / (np.std(init_full[:, 0]) * 10000)

    embedding = openTSNE.TSNEEmbedding(
        init_full,
        aff50,
        n_jobs=32,
        verbose=True,
        random_state=42,
    )
    
    embedding1 = embedding.optimize(n_iter=1500, exaggeration=12)
    return embedding1

# %%
def visualize_embedding_vit(emb_name):
    positive_features = ViTExtractor('projection_ava_positive', extractor_name=emb_name).extract_features(paths_train_positive)
    negative_features = ViTExtractor('projection_ava_negative', extractor_name=emb_name).extract_features(paths_train_negative)
    
    positive_features = positive_features.drop(['id'], axis=1).to_numpy()
    negative_features = negative_features.drop(['id'], axis=1).to_numpy()

    all_features = np.concatenate([positive_features, negative_features])
    labels = np.concatenate([np.ones(positive_features.shape[0]), np.zeros(negative_features.shape[0])])
    
    embs = tsne_huge(all_features, labels)
    
    sns.set(rc={'figure.figsize':(23.4,16.54)})
    scatter = sns.scatterplot(x=embs[:,0], y=embs[:,1], hue=labels, s=1.0, alpha=0.5, palette=sns.color_palette(["#FF0000", "#00FF00"], 2))
    
    fig = scatter.get_figure()
    fig.savefig(f"{emb_name}.png", dpi=300) 
    plt.clf()

# %%
for model_name in ['clip-ViT-B-32', 'clip-ViT-B-16', 'clip-ViT-L-14']:
    visualize_embedding_vit(model_name)
# Out:
# ===> Finding 1500 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 12.87 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 3.28 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, verbose=True)
# --------------------------------------------------------------------------------
# ===> Running optimization with exaggeration=12.00, lr=2083.33 for 250 iterations...
# Iteration   50, KL divergence 3.6962, 50 iterations in 2.1051 sec
# Iteration  100, KL divergence 3.6962, 50 iterations in 2.1154 sec
# Iteration  150, KL divergence 3.6962, 50 iterations in 2.0527 sec
# Iteration  200, KL divergence 3.6962, 50 iterations in 2.1538 sec
# Iteration  250, KL divergence 3.6962, 50 iterations in 2.0923 sec
#    --> Time elapsed: 10.52 seconds
# ===> Running optimization with exaggeration=1.00, lr=25000.00 for 500 iterations...
# Iteration   50, KL divergence 1.9970, 50 iterations in 2.1255 sec
# Iteration  100, KL divergence 1.9433, 50 iterations in 2.1078 sec
# Iteration  150, KL divergence 1.9201, 50 iterations in 2.1162 sec
# Iteration  200, KL divergence 1.9116, 50 iterations in 2.1194 sec
# Iteration  250, KL divergence 1.9074, 50 iterations in 2.2872 sec
# Iteration  300, KL divergence 1.9040, 50 iterations in 2.2508 sec
# Iteration  350, KL divergence 1.9021, 50 iterations in 2.3462 sec
# Iteration  400, KL divergence 1.9011, 50 iterations in 2.3792 sec
# Iteration  450, KL divergence 1.9003, 50 iterations in 2.3330 sec
# Iteration  500, KL divergence 1.8997, 50 iterations in 2.3008 sec
#    --> Time elapsed: 22.37 seconds
# ===> Finding 1 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.09 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=12.00, lr=17023.25 for 1500 iterations...
# Iteration   50, KL divergence 7.1645, 50 iterations in 2.6816 sec
# Iteration  100, KL divergence 7.1602, 50 iterations in 2.7631 sec
# Iteration  150, KL divergence 7.1518, 50 iterations in 2.7328 sec
# Iteration  200, KL divergence 7.1499, 50 iterations in 2.7136 sec
# Iteration  250, KL divergence 7.1494, 50 iterations in 2.7175 sec
# Iteration  300, KL divergence 7.1493, 50 iterations in 2.6999 sec
# Iteration  350, KL divergence 7.1492, 50 iterations in 2.6956 sec
# Iteration  400, KL divergence 7.1491, 50 iterations in 2.7160 sec
# Iteration  450, KL divergence 7.1491, 50 iterations in 2.7336 sec
# Iteration  500, KL divergence 7.1491, 50 iterations in 2.7311 sec
# Iteration  550, KL divergence 7.1492, 50 iterations in 2.6972 sec
# Iteration  600, KL divergence 7.1492, 50 iterations in 2.7145 sec
# Iteration  650, KL divergence 7.1492, 50 iterations in 2.6922 sec
# Iteration  700, KL divergence 7.1489, 50 iterations in 2.7112 sec
# Iteration  750, KL divergence 7.1473, 50 iterations in 2.7181 sec
# Iteration  800, KL divergence 7.1463, 50 iterations in 2.7520 sec
# Iteration  850, KL divergence 7.1462, 50 iterations in 2.7415 sec
# Iteration  900, KL divergence 7.1461, 50 iterations in 2.7357 sec
# Iteration  950, KL divergence 7.1461, 50 iterations in 2.7434 sec
# Iteration 1000, KL divergence 7.1461, 50 iterations in 2.7246 sec
# Iteration 1050, KL divergence 7.1461, 50 iterations in 2.7500 sec
# Iteration 1100, KL divergence 7.1461, 50 iterations in 2.7424 sec
# Iteration 1150, KL divergence 7.1461, 50 iterations in 2.7676 sec
# Iteration 1200, KL divergence 7.1461, 50 iterations in 2.7283 sec
# Iteration 1250, KL divergence 7.1461, 50 iterations in 2.7454 sec
# Iteration 1300, KL divergence 7.1461, 50 iterations in 2.7810 sec
# Iteration 1350, KL divergence 7.1461, 50 iterations in 2.7646 sec
# Iteration 1400, KL divergence 7.1461, 50 iterations in 2.7746 sec
# Iteration 1450, KL divergence 7.1461, 50 iterations in 2.7497 sec
# Iteration 1500, KL divergence 7.1461, 50 iterations in 2.7956 sec
#    --> Time elapsed: 82.02 seconds
# 100%|███████████████████████████████████████████| 67/67 [06:33<00:00,  5.87s/it]
# ===> Finding 1500 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 12.82 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 3.25 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, verbose=True)
# --------------------------------------------------------------------------------
# ===> Running optimization with exaggeration=12.00, lr=2083.33 for 250 iterations...
# Iteration   50, KL divergence 3.6761, 50 iterations in 2.0666 sec
# Iteration  100, KL divergence 3.6761, 50 iterations in 1.9876 sec
# Iteration  150, KL divergence 3.6761, 50 iterations in 2.0915 sec
# Iteration  200, KL divergence 3.6761, 50 iterations in 2.0389 sec
# Iteration  250, KL divergence 3.6761, 50 iterations in 2.0284 sec
#    --> Time elapsed: 10.21 seconds
# ===> Running optimization with exaggeration=1.00, lr=25000.00 for 500 iterations...
# Iteration   50, KL divergence 1.9736, 50 iterations in 2.0920 sec
# Iteration  100, KL divergence 1.9135, 50 iterations in 1.9758 sec
# Iteration  150, KL divergence 1.8920, 50 iterations in 2.1051 sec
# Iteration  200, KL divergence 1.8823, 50 iterations in 2.1805 sec
# Iteration  250, KL divergence 1.8774, 50 iterations in 2.2697 sec
# Iteration  300, KL divergence 1.8737, 50 iterations in 2.2203 sec
# Iteration  350, KL divergence 1.8719, 50 iterations in 2.3162 sec
# Iteration  400, KL divergence 1.8707, 50 iterations in 2.3159 sec
# Iteration  450, KL divergence 1.8694, 50 iterations in 2.3097 sec
# Iteration  500, KL divergence 1.8686, 50 iterations in 2.3361 sec
#    --> Time elapsed: 22.12 seconds
# ===> Finding 1 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 10.24 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=12.00, lr=17023.25 for 1500 iterations...
# Iteration   50, KL divergence 7.0493, 50 iterations in 2.6323 sec
# Iteration  100, KL divergence 7.1437, 50 iterations in 2.6993 sec
# Iteration  150, KL divergence 7.1425, 50 iterations in 2.6750 sec
# Iteration  200, KL divergence 7.1005, 50 iterations in 2.6908 sec
# Iteration  250, KL divergence 7.0948, 50 iterations in 2.6638 sec
# Iteration  300, KL divergence 7.0932, 50 iterations in 2.6916 sec
# Iteration  350, KL divergence 7.0928, 50 iterations in 2.6851 sec
# Iteration  400, KL divergence 7.0926, 50 iterations in 2.7080 sec
# Iteration  450, KL divergence 7.0926, 50 iterations in 2.6637 sec
# Iteration  500, KL divergence 7.0926, 50 iterations in 2.6595 sec
# Iteration  550, KL divergence 7.0926, 50 iterations in 2.6800 sec
# Iteration  600, KL divergence 7.0927, 50 iterations in 2.7054 sec
# Iteration  650, KL divergence 7.0927, 50 iterations in 2.6685 sec
# Iteration  700, KL divergence 7.0927, 50 iterations in 2.6497 sec
# Iteration  750, KL divergence 7.0925, 50 iterations in 2.6684 sec
# Iteration  800, KL divergence 7.0924, 50 iterations in 2.6651 sec
# Iteration  850, KL divergence 7.0923, 50 iterations in 2.6963 sec
# Iteration  900, KL divergence 7.0921, 50 iterations in 2.6823 sec
# Iteration  950, KL divergence 7.0919, 50 iterations in 2.6957 sec
# Iteration 1000, KL divergence 7.0919, 50 iterations in 2.7069 sec
# Iteration 1050, KL divergence 7.0918, 50 iterations in 2.7205 sec
# Iteration 1100, KL divergence 7.0918, 50 iterations in 2.6999 sec
# Iteration 1150, KL divergence 7.0918, 50 iterations in 2.6856 sec
# Iteration 1200, KL divergence 7.0918, 50 iterations in 2.7301 sec
# Iteration 1250, KL divergence 7.0918, 50 iterations in 2.7126 sec
# Iteration 1300, KL divergence 7.0918, 50 iterations in 2.7233 sec
# Iteration 1350, KL divergence 7.0918, 50 iterations in 2.7130 sec
# Iteration 1400, KL divergence 7.0918, 50 iterations in 2.7056 sec
# Iteration 1450, KL divergence 7.0919, 50 iterations in 2.6976 sec
# Iteration 1500, KL divergence 7.0918, 50 iterations in 2.6970 sec
#    --> Time elapsed: 80.67 seconds
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
#   7%|██▊                                       | 11/161 [02:26<33:17, 13.32s/it]/usr/local/lib/python3.8/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
#  43%|██████████████████▎                       | 70/161 [15:39<20:34, 13.57s/it]/usr/local/lib/python3.8/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 100%|█████████████████████████████████████████| 161/161 [37:05<00:00, 13.82s/it]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# 100%|███████████████████████████████████████████| 67/67 [14:53<00:00, 13.33s/it]
# ===> Finding 1500 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 18.12 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 3.74 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, verbose=True)
# --------------------------------------------------------------------------------
# ===> Running optimization with exaggeration=12.00, lr=2083.33 for 250 iterations...
# Iteration   50, KL divergence 3.6497, 50 iterations in 2.0424 sec
# Iteration  100, KL divergence 3.6497, 50 iterations in 2.0380 sec
# Iteration  150, KL divergence 3.6497, 50 iterations in 2.0671 sec
# Iteration  200, KL divergence 3.6497, 50 iterations in 2.0398 sec
# Iteration  250, KL divergence 3.6497, 50 iterations in 2.0040 sec
#    --> Time elapsed: 10.19 seconds
# ===> Running optimization with exaggeration=1.00, lr=25000.00 for 500 iterations...
# Iteration   50, KL divergence 2.0039, 50 iterations in 2.0819 sec
# Iteration  100, KL divergence 1.9351, 50 iterations in 2.0671 sec
# Iteration  150, KL divergence 1.9077, 50 iterations in 2.1249 sec
# Iteration  200, KL divergence 1.8977, 50 iterations in 2.0986 sec
# Iteration  250, KL divergence 1.8924, 50 iterations in 2.1488 sec
# Iteration  300, KL divergence 1.8892, 50 iterations in 2.1555 sec
# Iteration  350, KL divergence 1.8860, 50 iterations in 2.3032 sec
# Iteration  400, KL divergence 1.8838, 50 iterations in 2.3429 sec
# Iteration  450, KL divergence 1.8825, 50 iterations in 2.2635 sec
# Iteration  500, KL divergence 1.8814, 50 iterations in 2.3941 sec
#    --> Time elapsed: 21.98 seconds
# ===> Finding 1 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 14.82 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=12.00, lr=17023.25 for 1500 iterations...
# Iteration   50, KL divergence 7.0295, 50 iterations in 2.6598 sec
# Iteration  100, KL divergence 7.1113, 50 iterations in 2.7211 sec
# Iteration  150, KL divergence 7.1074, 50 iterations in 2.7479 sec
# Iteration  200, KL divergence 7.1075, 50 iterations in 2.7243 sec
# Iteration  250, KL divergence 7.1075, 50 iterations in 2.7277 sec
# Iteration  300, KL divergence 7.1076, 50 iterations in 2.7155 sec
# Iteration  350, KL divergence 7.1076, 50 iterations in 2.6982 sec
# Iteration  400, KL divergence 7.1076, 50 iterations in 2.7380 sec
# Iteration  450, KL divergence 7.1076, 50 iterations in 2.7179 sec
# Iteration  500, KL divergence 7.1076, 50 iterations in 2.6879 sec
# Iteration  550, KL divergence 7.1076, 50 iterations in 2.7327 sec
# Iteration  600, KL divergence 7.1076, 50 iterations in 2.7880 sec
# Iteration  650, KL divergence 7.1076, 50 iterations in 2.7451 sec
# Iteration  700, KL divergence 7.1077, 50 iterations in 2.7697 sec
# Iteration  750, KL divergence 7.1077, 50 iterations in 2.7849 sec
# Iteration  800, KL divergence 7.1077, 50 iterations in 2.7296 sec
# Iteration  850, KL divergence 7.1077, 50 iterations in 2.7468 sec
# Iteration  900, KL divergence 7.1077, 50 iterations in 2.7585 sec
# Iteration  950, KL divergence 7.1077, 50 iterations in 2.7651 sec
# Iteration 1000, KL divergence 7.1077, 50 iterations in 2.7383 sec
# Iteration 1050, KL divergence 7.1077, 50 iterations in 2.7643 sec
# Iteration 1100, KL divergence 7.1077, 50 iterations in 2.7295 sec
# Iteration 1150, KL divergence 7.1077, 50 iterations in 2.7416 sec
# Iteration 1200, KL divergence 7.1077, 50 iterations in 2.7457 sec
# Iteration 1250, KL divergence 7.1077, 50 iterations in 2.7484 sec
# Iteration 1300, KL divergence 7.1077, 50 iterations in 2.7366 sec
# Iteration 1350, KL divergence 7.1077, 50 iterations in 2.7674 sec
# Iteration 1400, KL divergence 7.1077, 50 iterations in 2.7566 sec
# Iteration 1450, KL divergence 7.1077, 50 iterations in 2.7541 sec
# Iteration 1500, KL divergence 7.1077, 50 iterations in 2.7212 sec
#    --> Time elapsed: 82.16 seconds

# %%
def visualize_embedding_autoencoder(filters):
    all_paths = np.concatenate([paths_train_positive, paths_train_negative])
    labels = np.concatenate([np.ones(len(paths_train_positive)), np.zeros(len(paths_train_negative))])
    extractor = AutoencoderExtractor('projection_ava', input_shape=(256, 256, 3), filters=filters)
    features = extractor.extract_features(all_paths)
    
    positive_features = features.drop(['id'], axis=1).to_numpy()[labels == 1]
    negative_features = features.drop(['id'], axis=1).to_numpy()[labels == 0]

    all_features = np.concatenate([positive_features, negative_features])
    
    embs = tsne_huge(all_features, labels)
    
    sns.set(rc={'figure.figsize':(23.4,16.54)})
    scatter = sns.scatterplot(x=embs[:,0], y=embs[:,1], hue=labels, s=1.0, alpha=0.5, palette=sns.color_palette(["#FF0000", "#00FF00"], 2))
    
    fig = scatter.get_figure()
    fig.savefig(f"{extractor.filename}.png", dpi=300) 
    plt.clf()

# %%
os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'
for filters in ([[8,16,16,32], [8,16,32,64,64], [8,16,32,64,64,128]]):
    visualize_embedding_autoencoder(filters)
# Out:
# 2023-12-20 10:03:50.898480: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:50.903450: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:50.903542: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:50.905288: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:50.905413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:50.905505: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:51.302112: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:51.302203: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:51.302242: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2023-12-20 10:03:51.302288: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-20 10:03:51.302331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9610 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# ===> Finding 1500 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 224.43 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 3.10 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, verbose=True)
# --------------------------------------------------------------------------------
# ===> Running optimization with exaggeration=12.00, lr=2083.33 for 250 iterations...
# Iteration   50, KL divergence 3.1868, 50 iterations in 2.0661 sec
# Iteration  100, KL divergence 3.1962, 50 iterations in 2.1077 sec
# Iteration  150, KL divergence 3.1964, 50 iterations in 2.0610 sec
# Iteration  200, KL divergence 3.2109, 50 iterations in 2.0729 sec
# Iteration  250, KL divergence 3.2113, 50 iterations in 2.0407 sec
#    --> Time elapsed: 10.35 seconds
# ===> Running optimization with exaggeration=1.00, lr=25000.00 for 500 iterations...
# Iteration   50, KL divergence 1.8605, 50 iterations in 2.0971 sec
# Iteration  100, KL divergence 1.8305, 50 iterations in 2.0900 sec
# Iteration  150, KL divergence 1.8287, 50 iterations in 2.0887 sec
# Iteration  200, KL divergence 1.8283, 50 iterations in 2.0612 sec
# Iteration  250, KL divergence 1.8282, 50 iterations in 2.0778 sec
# Iteration  300, KL divergence 1.8281, 50 iterations in 2.1068 sec
# Iteration  350, KL divergence 1.8281, 50 iterations in 2.0312 sec
# Iteration  400, KL divergence 1.8281, 50 iterations in 2.1185 sec
# Iteration  450, KL divergence 1.8281, 50 iterations in 2.0881 sec
# Iteration  500, KL divergence 1.8281, 50 iterations in 2.1874 sec
#    --> Time elapsed: 20.95 seconds
# ===> Finding 1 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 1001.75 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=17023.25 for 1500 iterations...
# Iteration   50, KL divergence 7.7718, 50 iterations in 2.9818 sec
# Iteration  100, KL divergence 7.1910, 50 iterations in 3.0059 sec
# Iteration  150, KL divergence 7.1908, 50 iterations in 3.0028 sec
# Iteration  200, KL divergence 7.2017, 50 iterations in 3.0179 sec
# Iteration  250, KL divergence 7.1966, 50 iterations in 2.9998 sec
# Iteration  300, KL divergence 7.1965, 50 iterations in 3.0134 sec
# Iteration  350, KL divergence 7.1980, 50 iterations in 2.9932 sec
# Iteration  400, KL divergence 7.2074, 50 iterations in 3.0088 sec
# Iteration  450, KL divergence 7.2092, 50 iterations in 3.0031 sec
# Iteration  500, KL divergence 7.2046, 50 iterations in 2.9962 sec
# Iteration  550, KL divergence 7.1975, 50 iterations in 2.9844 sec
# Iteration  600, KL divergence 7.1978, 50 iterations in 3.0127 sec
# Iteration  650, KL divergence 7.2046, 50 iterations in 3.0001 sec
# Iteration  700, KL divergence 7.1927, 50 iterations in 3.0130 sec
# Iteration  750, KL divergence 7.1988, 50 iterations in 2.9974 sec
# Iteration  800, KL divergence 7.2068, 50 iterations in 3.0209 sec
# Iteration  850, KL divergence 7.1928, 50 iterations in 3.0031 sec
# Iteration  900, KL divergence 7.1998, 50 iterations in 3.0150 sec
# Iteration  950, KL divergence 7.1952, 50 iterations in 2.9804 sec
# Iteration 1000, KL divergence 7.1891, 50 iterations in 2.9960 sec
# Iteration 1050, KL divergence 7.1964, 50 iterations in 2.9995 sec
# Iteration 1100, KL divergence 7.1990, 50 iterations in 2.9935 sec
# Iteration 1150, KL divergence 7.1874, 50 iterations in 3.0063 sec
# Iteration 1200, KL divergence 7.1961, 50 iterations in 3.0326 sec
# Iteration 1250, KL divergence 7.1956, 50 iterations in 3.0372 sec
# Iteration 1300, KL divergence 7.2096, 50 iterations in 3.0021 sec
# Iteration 1350, KL divergence 7.1978, 50 iterations in 3.0050 sec
# Iteration 1400, KL divergence 7.1968, 50 iterations in 3.0422 sec
# Iteration 1450, KL divergence 7.1981, 50 iterations in 2.9943 sec
# Iteration 1500, KL divergence 7.1928, 50 iterations in 3.0126 sec
#    --> Time elapsed: 90.17 seconds
# ===> Finding 1500 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 84.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 1.99 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, verbose=True)
# --------------------------------------------------------------------------------
# ===> Running optimization with exaggeration=12.00, lr=2083.33 for 250 iterations...
# Iteration   50, KL divergence 3.1091, 50 iterations in 2.0387 sec
# Iteration  100, KL divergence 3.1163, 50 iterations in 1.9571 sec
# Iteration  150, KL divergence 3.1184, 50 iterations in 2.0579 sec
# Iteration  200, KL divergence 3.1177, 50 iterations in 2.0571 sec
# Iteration  250, KL divergence 3.1194, 50 iterations in 2.1587 sec
#    --> Time elapsed: 10.27 seconds
# ===> Running optimization with exaggeration=1.00, lr=25000.00 for 500 iterations...
# Iteration   50, KL divergence 1.7250, 50 iterations in 2.1247 sec
# Iteration  100, KL divergence 1.7093, 50 iterations in 2.0989 sec
# Iteration  150, KL divergence 1.7073, 50 iterations in 2.1027 sec
# Iteration  200, KL divergence 1.7066, 50 iterations in 2.1010 sec
# Iteration  250, KL divergence 1.7062, 50 iterations in 2.0813 sec
# Iteration  300, KL divergence 1.7058, 50 iterations in 2.1625 sec
# Iteration  350, KL divergence 1.7057, 50 iterations in 2.0307 sec
# Iteration  400, KL divergence 1.7057, 50 iterations in 2.1679 sec
# Iteration  450, KL divergence 1.7056, 50 iterations in 2.0978 sec
# Iteration  500, KL divergence 1.7056, 50 iterations in 2.1243 sec
#    --> Time elapsed: 21.09 seconds
# ===> Finding 1 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 240.41 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=17023.25 for 1500 iterations...
# Iteration   50, KL divergence 7.1951, 50 iterations in 2.9340 sec
# Iteration  100, KL divergence 6.9073, 50 iterations in 2.9508 sec
# Iteration  150, KL divergence 6.9187, 50 iterations in 2.9850 sec
# Iteration  200, KL divergence 6.9222, 50 iterations in 2.9856 sec
# Iteration  250, KL divergence 6.9115, 50 iterations in 2.9564 sec
# Iteration  300, KL divergence 6.9177, 50 iterations in 3.0090 sec
# Iteration  350, KL divergence 6.9223, 50 iterations in 2.9644 sec
# Iteration  400, KL divergence 6.9223, 50 iterations in 2.9662 sec
# Iteration  450, KL divergence 6.9220, 50 iterations in 2.9667 sec
# Iteration  500, KL divergence 6.9198, 50 iterations in 2.9949 sec
# Iteration  550, KL divergence 6.9171, 50 iterations in 2.9751 sec
# Iteration  600, KL divergence 6.9186, 50 iterations in 2.9745 sec
# Iteration  650, KL divergence 6.9193, 50 iterations in 2.9610 sec
# Iteration  700, KL divergence 6.9161, 50 iterations in 2.9746 sec
# Iteration  750, KL divergence 6.9096, 50 iterations in 2.9940 sec
# Iteration  800, KL divergence 6.9205, 50 iterations in 2.9672 sec
# Iteration  850, KL divergence 6.9131, 50 iterations in 2.9965 sec
# Iteration  900, KL divergence 6.9226, 50 iterations in 2.9932 sec
# Iteration  950, KL divergence 6.9208, 50 iterations in 2.9914 sec
# Iteration 1000, KL divergence 6.9201, 50 iterations in 3.0083 sec
# Iteration 1050, KL divergence 6.9186, 50 iterations in 2.9820 sec
# Iteration 1100, KL divergence 6.9212, 50 iterations in 2.9950 sec
# Iteration 1150, KL divergence 6.9189, 50 iterations in 3.0029 sec
# Iteration 1200, KL divergence 6.9143, 50 iterations in 3.0364 sec
# Iteration 1250, KL divergence 6.9215, 50 iterations in 2.9681 sec
# Iteration 1300, KL divergence 6.9178, 50 iterations in 2.9682 sec
# Iteration 1350, KL divergence 6.9186, 50 iterations in 2.9787 sec
# Iteration 1400, KL divergence 6.9141, 50 iterations in 2.9787 sec
# Iteration 1450, KL divergence 6.9209, 50 iterations in 2.9949 sec
# Iteration 1500, KL divergence 6.9203, 50 iterations in 2.9965 sec
#    --> Time elapsed: 89.45 seconds
# ===> Finding 1500 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 34.07 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 1.90 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, verbose=True)
# --------------------------------------------------------------------------------
# ===> Running optimization with exaggeration=12.00, lr=2083.33 for 250 iterations...
# Iteration   50, KL divergence 3.1797, 50 iterations in 2.1573 sec
# Iteration  100, KL divergence 3.2100, 50 iterations in 2.1174 sec
# Iteration  150, KL divergence 3.2126, 50 iterations in 2.1064 sec
# Iteration  200, KL divergence 3.2166, 50 iterations in 2.0632 sec
# Iteration  250, KL divergence 3.2161, 50 iterations in 2.1024 sec
#    --> Time elapsed: 10.55 seconds
# ===> Running optimization with exaggeration=1.00, lr=25000.00 for 500 iterations...
# Iteration   50, KL divergence 1.6793, 50 iterations in 2.1141 sec
# Iteration  100, KL divergence 1.6656, 50 iterations in 2.1675 sec
# Iteration  150, KL divergence 1.6636, 50 iterations in 2.1065 sec
# Iteration  200, KL divergence 1.6632, 50 iterations in 2.1433 sec
# Iteration  250, KL divergence 1.6629, 50 iterations in 2.0800 sec
# Iteration  300, KL divergence 1.6628, 50 iterations in 2.1478 sec
# Iteration  350, KL divergence 1.6628, 50 iterations in 2.1684 sec
# Iteration  400, KL divergence 1.6628, 50 iterations in 2.1069 sec
# Iteration  450, KL divergence 1.6627, 50 iterations in 2.1600 sec
# Iteration  500, KL divergence 1.6627, 50 iterations in 2.0114 sec
#    --> Time elapsed: 21.21 seconds
# ===> Finding 1 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 63.79 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=17023.25 for 1500 iterations...
# Iteration   50, KL divergence 7.1853, 50 iterations in 2.9729 sec
# Iteration  100, KL divergence 6.9137, 50 iterations in 2.9915 sec
# Iteration  150, KL divergence 6.9211, 50 iterations in 2.9722 sec
# Iteration  200, KL divergence 6.9232, 50 iterations in 2.9699 sec
# Iteration  250, KL divergence 6.9236, 50 iterations in 3.0168 sec
# Iteration  300, KL divergence 6.9277, 50 iterations in 2.9544 sec
# Iteration  350, KL divergence 6.9220, 50 iterations in 2.9497 sec
# Iteration  400, KL divergence 6.9261, 50 iterations in 2.9611 sec
# Iteration  450, KL divergence 6.9208, 50 iterations in 2.9578 sec
# Iteration  500, KL divergence 6.9286, 50 iterations in 2.9780 sec
# Iteration  550, KL divergence 6.9264, 50 iterations in 2.9401 sec
# Iteration  600, KL divergence 6.9263, 50 iterations in 2.9689 sec
# Iteration  650, KL divergence 6.9323, 50 iterations in 2.9522 sec
# Iteration  700, KL divergence 6.9223, 50 iterations in 2.9557 sec
# Iteration  750, KL divergence 6.9247, 50 iterations in 2.9325 sec
# Iteration  800, KL divergence 6.9279, 50 iterations in 2.9990 sec
# Iteration  850, KL divergence 6.9257, 50 iterations in 2.9597 sec
# Iteration  900, KL divergence 6.9252, 50 iterations in 2.9569 sec
# Iteration  950, KL divergence 6.9197, 50 iterations in 2.9838 sec
# Iteration 1000, KL divergence 6.9213, 50 iterations in 2.9473 sec
# Iteration 1050, KL divergence 6.9245, 50 iterations in 2.9667 sec
# Iteration 1100, KL divergence 6.9299, 50 iterations in 2.9475 sec
# Iteration 1150, KL divergence 6.9317, 50 iterations in 2.9881 sec
# Iteration 1200, KL divergence 6.9198, 50 iterations in 2.9637 sec
# Iteration 1250, KL divergence 6.9267, 50 iterations in 2.9524 sec
# Iteration 1300, KL divergence 6.9207, 50 iterations in 2.9797 sec
# Iteration 1350, KL divergence 6.9213, 50 iterations in 2.9508 sec
# Iteration 1400, KL divergence 6.9178, 50 iterations in 2.9474 sec
# Iteration 1450, KL divergence 6.9264, 50 iterations in 2.9601 sec
# Iteration 1500, KL divergence 6.9266, 50 iterations in 2.9594 sec
#    --> Time elapsed: 88.94 seconds
